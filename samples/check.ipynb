# %%
# Setup

import numpy as np
import matplotlib.pyplot as plt

from glob import glob
from tqdm import tqdm
import cv2

import torch
import torch.nn as nn
import torch.nn.functional as F

from customModel import *

import albumentations as A
import albumentations.augmentations.functional as F
from albumentations.pytorch import ToTensorV2

# %%
inputs = np.load('./inputs.npy').astype('float32')
inputs.shape
# Out:
# (100, 3, 512, 512)

# %%
target = (inputs[0][1]*255).astype('uint8')
target.shape
# Out:
# (512, 512)

# %%
Image.fromarray(target)
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
transformer = A.HorizontalFlip(p=1)
target2 = transformer(image=target)
Image.fromarray(target2['image'])
# Out:
# <PIL.Image.Image image mode=L size=512x512>

# %%
transformer = A.ShiftScaleRotate(shift_limit=0.01, scale_limit=0.3, rotate_limit=5, p=1, border_mode=0)
target2 = transformer(image=target)
Image.fromarray(target2['image'])
# Out:
# <PIL.Image.Image image mode=L size=512x512>
